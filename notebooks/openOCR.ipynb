# %%
from openocr import OpenOCR
engine = OpenOCR()

img_path = '../data/ocr_test/images/crop_0001.jpg'

result, elapse = engine(img_path)

print(f"\n⏱️ Tempo de processamento: {elapse}")
print("📝 Resultado OCR:", result)
# Out:
# [2025/10/29 21:44:58] openrec INFO: Model already exists at: C:\Users\rafael\.cache\openocr\openocr_det_repvit_ch.pth
# [2025/10/29 21:44:58] openrec INFO: backbone.features.0.0.bn.num_batches_tracked is not in pretrained model
# [2025/10/29 21:44:58] openrec INFO: backbone.features.0.2.bn.num_batches_tracked is not in pretrained model
# [2025/10/29 21:44:58] openrec INFO: backbone.features.1.token_mixer.0.conv.bn.num_batches_tracked is not in pretrained model
# [2025/10/29 21:44:58] openrec INFO: backbone.features.1.token_mixer.0.bn.num_batches_tracked is not in pretrained model
# [2025/10/29 21:44:58] openrec INFO: backbone.features.1.channel_mixer.m.0.bn.num_batches_tracked is not in pretrained model
# [2025/10/29 21:44:58] openrec INFO: backbone.features.1.channel_mixer.m.2.bn.num_batches_tracked is not in pretrained model
# [2025/10/29 21:44:58] openrec INFO: backbone.features.2.token_mixer.0.conv.bn.num_batches_tracked is not in pretrained model
# ...
